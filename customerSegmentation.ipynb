# %%
#initial look at the dataset
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

dataset = pd.read_csv('online_retail.csv')
print(dataset.head())
print(dataset.describe())
print(dataset.info())
print(dataset.isnull().sum())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB
# None
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
#Data cleaning
dataset = dataset.dropna()
dataset = dataset[dataset['Quantity'] > 0]
dataset = dataset[dataset['UnitPrice'] > 0]
dataset = dataset.drop(columns=['Description'])
dataset.describe()
print(dataset['CustomerID'].nunique())
# Out:
# 4338

# %%
#Outlier detection
outlierColumns = ["Quantity" , "UnitPrice"]
for col in outlierColumns:
    Q3 = dataset[col].quantile(0.75)
    Q1 = dataset[col].quantile(0.25)
    IQR = Q3-Q1
    upperBound = Q3 + 1.5*IQR
    lowerBound = Q1-1.5*IQR
    above_upper = (dataset[col] > upperBound).sum()
    below_lower = (dataset[col] < lowerBound).sum()
    print(f"{col}:")
    print("  Above upper bound:", above_upper)
    print("  Below lower bound:", below_lower)
# Out:
# Quantity:
#   Above upper bound: 25647
#   Below lower bound: 0
# UnitPrice:
#   Above upper bound: 34356
#   Below lower bound: 0

# %%
#Outlier rows
Q1 = dataset['Quantity'].quantile(0.25)
Q3 = dataset['Quantity'].quantile(0.75)
IQR = Q3 - Q1

lower_bound_q = Q1 - 1.5 * IQR
upper_bound_q = Q3 + 1.5 * IQR

quantity_outliers = dataset[
    (dataset['Quantity'] > upper_bound_q) |
    (dataset['Quantity'] < lower_bound_q)
]
#These represent bulk purchases, customers who buy in bulk purchases are valuable to us.
quantity_outliers
# Out:
#        InvoiceNo StockCode  Quantity          InvoiceDate  UnitPrice  \
# 9         536367     84879        32  2010-12-01 08:34:00       1.69
# 31        536370     10002        48  2010-12-01 08:45:00       0.85
# 44        536370     22492        36  2010-12-01 08:45:00       0.65
# 46        536371     22086        80  2010-12-01 09:00:00       2.55
# 65        536374     21258        32  2010-12-01 09:09:00      10.95
# ...          ...       ...       ...                  ...        ...
# 541835    581579     23581        40  2011-12-09 12:19:00       1.79
# 541865    581583     20725        40  2011-12-09 12:23:00       1.45
# 541866    581583     85038        36  2011-12-09 12:23:00       1.85
# 541867    581584     20832        72  2011-12-09 12:25:00       0.72
# 541868    581584     85038        48  2011-12-09 12:25:00       1.85
#
#         CustomerID         Country
# 9          13047.0  United Kingdom
# 31         12583.0          France
# 44         12583.0          France
# 46         13748.0  United Kingdom
# 65         15100.0  United Kingdom
# ...            ...             ...
# 541835     17581.0  United Kingdom
# 541865     13777.0  United Kingdom
# 541866     13777.0  United Kingdom
# 541867     13777.0  United Kingdom
# 541868     13777.0  United Kingdom
#
# [25647 rows x 7 columns]

# %%
#Outlier rows
Q1 = dataset['UnitPrice'].quantile(0.25)
Q3 = dataset['UnitPrice'].quantile(0.75)
IQR = Q3 - Q1

lower_bound_u = Q1 - 1.5 * IQR
upper_bound_u = Q3 + 1.5 * IQR

unitPrice_outliers = dataset[
    (dataset['UnitPrice'] > upper_bound_u) |
    (dataset['UnitPrice'] < lower_bound_u)
]
#These represent customers that buy products that are very expensive, which are also valuable customers to us
unitPrice_outliers
# Out:
#        InvoiceNo StockCode  Quantity          InvoiceDate  UnitPrice  \
# 5         536365     22752         2  2010-12-01 08:26:00       7.65
# 16        536367     22622         2  2010-12-01 08:34:00       9.95
# 19        536367     21777         4  2010-12-01 08:34:00       7.95
# 20        536367     48187         4  2010-12-01 08:34:00       7.95
# 45        536370      POST         3  2010-12-01 08:45:00      18.00
# ...          ...       ...       ...                  ...        ...
# 541768    581578      POST         3  2011-12-09 12:16:00      18.00
# 541786    581578     22622         6  2011-12-09 12:16:00      11.95
# 541831    581579     22941         4  2011-12-09 12:19:00       8.50
# 541849    581580     22894         2  2011-12-09 12:20:00       9.95
# 541892    581586     21217        24  2011-12-09 12:49:00       8.95
#
#         CustomerID         Country
# 5          17850.0  United Kingdom
# 16         13047.0  United Kingdom
# 19         13047.0  United Kingdom
# 20         13047.0  United Kingdom
# 45         12583.0          France
# ...            ...             ...
# 541768     12713.0         Germany
# 541786     12713.0         Germany
# 541831     17581.0  United Kingdom
# 541849     12748.0  United Kingdom
# 541892     13113.0  United Kingdom
#
# [34356 rows x 7 columns]

# %%
#Capping the outliers
dataset["UnitPrice_c"] = dataset["UnitPrice"].clip(
    lower=0,
    upper=upper_bound_u
)
dataset["Quantity_c"] = dataset["Quantity"].clip(
    lower=0,
    upper=upper_bound_q
)
dataset
# Out:
#        InvoiceNo StockCode  Quantity          InvoiceDate  UnitPrice  \
# 0         536365    85123A         6  2010-12-01 08:26:00       2.55
# 1         536365     71053         6  2010-12-01 08:26:00       3.39
# 2         536365    84406B         8  2010-12-01 08:26:00       2.75
# 3         536365    84029G         6  2010-12-01 08:26:00       3.39
# 4         536365    84029E         6  2010-12-01 08:26:00       3.39
# ...          ...       ...       ...                  ...        ...
# 541904    581587     22613        12  2011-12-09 12:50:00       0.85
# 541905    581587     22899         6  2011-12-09 12:50:00       2.10
# 541906    581587     23254         4  2011-12-09 12:50:00       4.15
# 541907    581587     23255         4  2011-12-09 12:50:00       4.15
# 541908    581587     22138         3  2011-12-09 12:50:00       4.95
#
#         CustomerID         Country  UnitPrice_c  Quantity_c
# 0          17850.0  United Kingdom         2.55           6
# 1          17850.0  United Kingdom         3.39           6
# 2          17850.0  United Kingdom         2.75           8
# 3          17850.0  United Kingdom         3.39           6
# 4          17850.0  United Kingdom         3.39           6
# ...            ...             ...          ...         ...
# 541904     12680.0          France         0.85          12
# 541905     12680.0          France         2.10           6
# 541906     12680.0          France         4.15           4
# 541907     12680.0          France         4.15           4
# 541908     12680.0          France         4.95           3
#
# [397884 rows x 9 columns]

# %%
#Calculating RFM
dataset["transactionCost"] = dataset["Quantity_c"] * dataset['UnitPrice_c']
dataset["formatedDate"] = pd.to_datetime(dataset["InvoiceDate"])
sortedDataset = dataset.sort_values(by="formatedDate" , ascending=False)
referenceDate = sortedDataset["formatedDate"].iloc[0] + pd.Timedelta(days=1)
rfm = sortedDataset.groupby("CustomerID").agg({
    "formatedDate" : "first",
    "transactionCost" : "sum",
    "InvoiceNo" : 'nunique'
})
rfm['R'] = (referenceDate - rfm["formatedDate"]).dt.days
rfm = rfm.drop(columns=['formatedDate'])
rfm = rfm.rename(
    columns={
    "transactionCost" : "M",
    "InvoiceNo" : "F"
    }
)
rfm
# Out:
#                   M   F    R
# CustomerID
# 12346.0       28.08   1  326
# 12347.0     3877.44   7    2
# 12348.0      557.57   4   75
# 12349.0     1336.65   1   19
# 12350.0      301.90   1  310
# ...             ...  ..  ...
# 18280.0      174.50   1  278
# 18281.0       61.92   1  181
# 18282.0      150.96   2    8
# 18283.0     2081.98  16    4
# 18287.0     1520.23   3   43
#
# [4338 rows x 3 columns]

# %%
plt.figure(figsize=(18, 5))

# Recency distribution
plt.subplot(1, 3, 1)
plt.hist(rfm["R"], bins=50)
plt.xlabel("Recency (days)")
plt.ylabel("Count")
plt.title("Recency Distribution")

# Frequency distribution
plt.subplot(1, 3, 2)
plt.hist(rfm["F"], bins=50)
plt.xlabel("Frequency")
plt.ylabel("Count")
plt.title("Frequency Distribution")

# Monetary distribution
plt.subplot(1, 3, 3)
plt.hist(rfm["M"], bins=50)
plt.xlabel("Monetary Value")
plt.ylabel("Count")
plt.title("Monetary Distribution")

plt.tight_layout()
plt.show()

# %%
import numpy as np

rfm["F"] = np.log1p(rfm["F"])
rfm["M"] = np.log1p(rfm["M"])

# %%
plt.figure(figsize=(18, 5))

# Recency distribution
plt.subplot(1, 3, 1)
plt.hist(rfm["R"], bins=50)
plt.xlabel("Recency (days)")
plt.ylabel("Count")
plt.title("Recency Distribution")

# Frequency distribution
plt.subplot(1, 3, 2)
plt.hist(rfm["F"], bins=50)
plt.xlabel("Frequency")
plt.ylabel("Count")
plt.title("Frequency Distribution")

# Monetary distribution
plt.subplot(1, 3, 3)
plt.hist(rfm["M"], bins=50)
plt.xlabel("Monetary Value")
plt.ylabel("Count")
plt.title("Monetary Distribution")

plt.tight_layout()
plt.show()

# %%
rfm
# Out:
#                    M         F    R
# CustomerID
# 12346.0     3.370051  0.693147  326
# 12347.0     8.263188  2.079442    2
# 12348.0     6.325380  1.609438   75
# 12349.0     7.198670  0.693147   19
# 12350.0     5.713403  0.693147  310
# ...              ...       ...  ...
# 18280.0     5.167639  0.693147  278
# 18281.0     4.141864  0.693147  181
# 18282.0     5.023617  1.098612    8
# 18283.0     7.641555  2.833213    4
# 18287.0     7.327274  1.386294   43
#
# [4338 rows x 3 columns]
